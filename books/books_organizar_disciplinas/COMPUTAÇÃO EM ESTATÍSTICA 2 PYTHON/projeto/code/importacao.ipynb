# %%
import pandas

# Caminho relativo ao diretório do script
path_data = "../../data/bruto/br-capes-concessao-bolsas-ies-2022-2023-03-01.csv"

# Importando o arquivo CSV
data = pandas.read_csv(path_data, sep=";", encoding="latin1")

# Exibindo as primeiras linhas do DataFrame
data.head(n=2)
# Out:
#    AN_REFERENCIA NM_MUNICIPIO_IES_CAPES SG_UF_IES_CAPES NM_REGIAO_IES_CAPES  \
# 0           2022                 MANAUS              AM               NORTE
# 1           2022                  BELÉM              PA               NORTE
#
#                          NM_IES_CAPES  CD_IES_CAPES SG_IES_CAPES  \
# 0  UNIVERSIDADE DO ESTADO DO AMAZONAS      12008010          UEA
# 1        UNIVERSIDADE FEDERAL DO PARÁ      15001016         UFPA
#
#   NM_NATUREZA_JURIDICA SG_PROGRAMA_FOMENTO    CD_PROGRAMA        NM_PROGRAMA  \
# 0             ESTADUAL                  AE  12008010001P9  MEDICINA TROPICAL
# 1              FEDERAL                  AE  15001016015P0  DOENÇAS TROPICAIS
#
#       NM_GRANDE_AREA NM_AREA_AVALIACAO                NM_AREA_CONHECIMENTO  \
# 0  CIÊNCIAS DA SAÚDE       MEDICINA II  DOENÇAS INFECCIOSAS E PARASITÁRIAS
# 1  CIÊNCIAS DA SAÚDE       MEDICINA II  DOENÇAS INFECCIOSAS E PARASITÁRIAS
#
#   NM_NIVEL_PADRAO  QT_BOLSAS_CONCEDIDAS  TP_PROGRAMA
# ...

# %%
# Nome das colunas dos Dados
data.columns
data.head(n=0)
data.columns.to_list()
# Out:
# ['AN_REFERENCIA',
#  'NM_MUNICIPIO_IES_CAPES',
#  'SG_UF_IES_CAPES',
#  'NM_REGIAO_IES_CAPES',
#  'NM_IES_CAPES',
#  'CD_IES_CAPES',
#  'SG_IES_CAPES',
#  'NM_NATUREZA_JURIDICA',
#  'SG_PROGRAMA_FOMENTO',
#  'CD_PROGRAMA',
#  'NM_PROGRAMA',
#  'NM_GRANDE_AREA',
#  'NM_AREA_AVALIACAO',
#  'NM_AREA_CONHECIMENTO',
#  'NM_NIVEL_PADRAO',
#  'QT_BOLSAS_CONCEDIDAS',
#  'TP_PROGRAMA']

# %%
import numpy
# escolhendo colunas aleatórias da Base de Dados.
data[numpy.random.choice(data.columns.to_list(), size=5, replace=False).tolist()]
# Out:
#        QT_BOLSAS_CONCEDIDAS  AN_REFERENCIA SG_PROGRAMA_FOMENTO  \
# 0                         3           2022                  AE
# 1                         3           2022                  AE
# 2                         1           2022                  AE
# 3                         3           2022                  AE
# 4                         1           2022                  AE
# ...                     ...            ...                 ...
# 13810                     1           2022      PDPG-SEMIARIDO
# 13811                     2           2022      PDPG-SEMIARIDO
# 13812                     1           2022      PDPG-SEMIARIDO
# 13813                     1           2022      PDPG-SEMIARIDO
# 13814                     1           2022      PDPG-SEMIARIDO
#
#                                             NM_IES_CAPES  \
# 0                     UNIVERSIDADE DO ESTADO DO AMAZONAS
# 1                           UNIVERSIDADE FEDERAL DO PARÁ
# ...
